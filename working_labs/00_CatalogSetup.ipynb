# %%
# %sql
-- Unity Catalog Setup
CREATE CATALOG IF NOT EXISTS bi_analytics;
CREATE SCHEMA IF NOT EXISTS bi_analytics.bronze;
CREATE SCHEMA IF NOT EXISTS bi_analytics.silver; 
CREATE SCHEMA IF NOT EXISTS bi_analytics.gold;

CREATE VOLUME IF NOT EXISTS bi_analytics.bronze.raw_demand_files
COMMENT 'Volume for raw demand data files';

CREATE VOLUME IF NOT EXISTS bi_analytics.bronze.raw_market_files
COMMENT 'Volume for raw market info data files';

--USE bi_analytics.bronze;

-- Display the Unity Catalog structure
SHOW SCHEMAS IN bi_analytics;
